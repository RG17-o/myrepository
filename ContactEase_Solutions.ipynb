# %% [markdown]
# **Progetto**

# %%
import sys

Contacts = {}

def AddContact():
    nome_cognome = input("Inserisci il nome e cognome del contatto: ")
    telefono = input("Inserisci il numero di telefono del contatto: ")


    while not (telefono.isdigit() and len(telefono)== 10) :
        telefono = input("Inserisci nuovamente il numero di telefono (deve essere un numero e di dieci cifre): ")

    Contacts[nome_cognome] = telefono
    print("Contatto aggiunto con successo!")
    return

def ShowContacts():
    return Contacts

def ChangeDetails():
    item_to_change=input("Inserisci il nome e cognome del contatto su cui vuoi apportare modifiche: ")
    scelta= input("Scegli l'opzione: RINOMINA o CAMBIA CONTATTO")
    while not (scelta=="RINOMINA" or scelta=="CAMBIA CONTATTO"):
      scelta=input("Scegli l'opzione: RINOMINA o CAMBIA CONTATTO")

    if scelta=="RINOMINA":
      new_name=input("Inserire il nuovo nome: ")
      Contacts[new_name]=Contacts[item_to_change]
      del Contacts[item_to_change]
